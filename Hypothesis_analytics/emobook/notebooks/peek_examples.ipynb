# %%
# === Inspect VAD scoring on real chunks ===================================
from pathlib import Path
import pandas as pd, numpy as np, re, unicodedata, textwrap

ROOT      = Path("..")  # run from emobook/notebooks/
CHUNK_DIR = ROOT / "chunks"
SCORE_DIR = ROOT / "scored_v21"

# Reuse UNI/MWE/MAX_MWE/NEGATORS if already loaded; else load them quickly
try:
    UNI, MWE, MAX_MWE
except NameError:
    # quick loader that matches the v2.1 scorer cell
    RES_DIR = ROOT / "resources"
    def find_v21_path():
        for p in [RES_DIR/"NRC-VAD-Lexicon-v2.1"/"NRC-VAD-Lexicon-v2.1.txt",
                  RES_DIR/"NRC-VAD-Lexicon-v2.1.txt"]:
            if p.exists(): return p
        raise FileNotFoundError("Put NRC-VAD-Lexicon-v2.1.txt under ../resources/NRC-VAD-Lexicon-v2.1/")
    df = pd.read_csv(find_v21_path(), sep="\t")
    df["term"] = df["term"].astype(str).str.strip().str.lower()
    is_mwe = df["term"].str.contains(r"\s")
    UNI = {t:(float(v),float(a),float(d)) for t,v,a,d in df.loc[~is_mwe,["term","valence","arousal","dominance"]].itertuples(index=False)}
    def tokseq(s): return tuple(re.findall(r"[a-z]+(?:'[a-z]+)?", s))
    MWE = {tokseq(t):(float(v),float(a),float(d)) for t,v,a,d in df.loc[is_mwe,["term","valence","arousal","dominance"]].itertuples(index=False)}
    MAX_MWE = max((len(k) for k in MWE.keys()), default=1)

NEGATORS = set("not no never none nobody nothing neither nor n't cannot can't don't won't isn't wasn't aren't weren't".split())

TOKEN_RE = re.compile(r"[a-z]+(?:'[a-z]+)?", re.I)
def tokenize(text: str):
    t = unicodedata.normalize("NFC", text)
    return [tok.lower() for tok in TOKEN_RE.findall(t)]

def match_and_explain(text: str, handle_negation=True, window_after_neg=3):
    """
    Returns:
      matches: list of dicts {term,type,span,negated,v,a,d,v_used}
      agg: {v,a,d,n_tokens,n_hits,coverage,mwe_share}
    """
    toks = tokenize(text)
    i, matches, n_tokens = 0, [], 0
    flip = 0

    while i < len(toks):
        tok = toks[i]
        n_tokens += 1

        if handle_negation and tok in NEGATORS:
            flip = window_after_neg
            i += 1
            continue

        # try MWE (longest first)
        used = False
        if MAX_MWE > 1:
            L = min(MAX_MWE, len(toks)-i)
            for n in range(L, 1, -1):
                key = tuple(toks[i:i+n])
                trip = MWE.get(key)
                if trip:
                    v,a,d = trip
                    neg = False
                    if flip > 0:
                        v = -v; neg = True; flip -= 1
                    matches.append({
                        "term": " ".join(key), "type": "mwe",
                        "span": (i, i+n), "negated": neg,
                        "v": trip[0], "a": trip[1], "d": trip[2],
                        "v_used": v
                    })
                    i += n
                    used = True
                    break
        if used: continue

        trip = UNI.get(tok)
        if trip:
            v,a,d = trip
            neg = False
            if flip > 0:
                v = -v; neg = True; flip -= 1
            matches.append({
                "term": tok, "type": "uni",
                "span": (i, i+1), "negated": neg,
                "v": trip[0], "a": trip[1], "d": trip[2],
                "v_used": v
            })
        else:
            if flip > 0: flip -= 1

        i += 1

    if matches:
        arr_v = np.array([m["v_used"] for m in matches], float)
        arr_a = np.array([m["a"] for m in matches], float)
        arr_d = np.array([m["d"] for m in matches], float)
        v_mean, a_mean, d_mean = arr_v.mean(), arr_a.mean(), arr_d.mean()
    else:
        v_mean = a_mean = d_mean = None

    mwe_share = (sum(1 for m in matches if m["type"]=="mwe")/len(matches)) if matches else 0.0

    agg = dict(
        v=v_mean, a=a_mean, d=d_mean,
        n_tokens=n_tokens, n_hits=len(matches),
        coverage=len(matches)/max(1,n_tokens),
        mwe_share=mwe_share
    )
    return matches, agg

def explain_chunk(book_stem: str, chunk_id: int, wrap=100, per_sentence=False):
    csv = SCORE_DIR / f"{book_stem}.scored_v21.csv"
    df = pd.read_csv(csv)
    row = df.loc[df["chunk_id"]==chunk_id].iloc[0]
    text = row["text"]
    print(f"\n=== {book_stem} | chunk {chunk_id} ===")
    print(textwrap.fill(text, width=wrap))
    print("\n-- matches --")
    matches, agg = match_and_explain(text, handle_negation=True)
    if not matches:
        print("(no lexicon hits)")
    else:
        for m in matches:
            tag = "MWE" if m["type"]=="mwe" else "UNI"
            neg = " [NEG]" if m["negated"] else ""
            print(f"{tag:<3} {m['term']:<25} v={m['v']:+.3f} a={m['a']:+.3f} d={m['d']:+.3f}  -> v_used={m['v_used']:+.3f}{neg}")

    print(f"\nAggregate: v={agg['v']:+.3f} a={agg['a']:+.3f} d={agg['d']:+.3f} | "
          f"hits={agg['n_hits']} / tokens={agg['n_tokens']} "
          f"coverage={agg['coverage']:.3f} | MWE%={agg['mwe_share']:.0%}")

    if per_sentence:
        # optional: show sentence-level scoring inside this chunk
        print("\n-- per sentence --")
        try:
            # use your pluggable sentence splitter if defined in this kernel
            sents = split_sentences(text)
        except Exception:
            # minimal fallback
            sents = re.split(r'(?<=[.!?])\s+', text)
        for i, s in enumerate(sents, 1):
            m2, a2 = match_and_explain(s, handle_negation=True)
            print(f"[s{i:02d}] v={None if a2['v'] is None else round(a2['v'],3)} "
                  f"a={None if a2['a'] is None else round(a2['a'],3)} "
                  f"d={None if a2['d'] is None else round(a2['d'],3)} "
                  f"(cov={a2['coverage']:.2f}) :: {s[:80]}{'...' if len(s)>80 else ''}")

def peek_examples(book_stem: str, mode="high_v", k=3, per_sentence=False):
    """
    mode: 'high_v' | 'low_v' | 'high_a' | 'low_cov' | 'random'
    """
    f = SCORE_DIR / f"{book_stem}.scored_v21.csv"
    df = pd.read_csv(f)

    sel = None
    if mode == "high_v":
        sel = df.sort_values("v", ascending=False).head(k)
    elif mode == "low_v":
        sel = df.sort_values("v", ascending=True).head(k)
    elif mode == "high_a":
        sel = df.sort_values("a", ascending=False).head(k)
    elif mode == "low_cov":
        sel = df.sort_values("coverage", ascending=True).head(k)
    elif mode == "random":
        sel = df.sample(n=min(k, len(df)), random_state=42)
    else:
        raise ValueError("Unknown mode")

    display(sel[["chunk_id","v","a","d","coverage"]])
    for cid in sel["chunk_id"].tolist():
        explain_chunk(book_stem, int(cid), per_sentence=per_sentence)

# %%
# Examples:
peek_examples("Frankenstein.clean", mode="high_v", k=2, per_sentence=False)
peek_examples("Mobi Dick.clean", mode="low_v", k=2)
peek_examples("Romeo and Juliet.clean", mode="low_cov", k=3, per_sentence=True)

# Or inspect a specific chunk id:
explain_chunk("Pride and Prejudice.clean", chunk_id=123, per_sentence=True)
# Out:
#       chunk_id         v         a         d  coverage
# 1006      1006  0.289813 -0.009933  0.107880  0.675676
# 153        153  0.285983 -0.049633  0.117517  0.674157
# === Frankenstein.clean | chunk 1006 ===
# You, perhaps, regard her as your sister, without any wish that she might become your wife. Nay, you
# may have met with another whom you may love; and considering yourself as bound in honour to
# Elizabeth, this struggle may occasion the poignant misery which you appear to feel." "My dear
# father, reassure yourself. I love my cousin tenderly and sincerely. I never saw any woman who
# excited, as Elizabeth does, my warmest admiration and affection. My future hopes and prospects are
# entirely bound up in the expectation of our union." "The expression of your sentiments of this
# subject, my dear Victor, gives me more pleasure than I have for some time experienced.
#
# -- matches --
# UNI perhaps                   v=+0.000 a=-0.333 d=-0.333  -> v_used=+0.000
# UNI regard                    v=+0.604 a=-0.328 d=+0.618  -> v_used=+0.604
# UNI as                        v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI your                      v=+0.000 a=+0.000 d=+0.259  -> v_used=+0.000
# UNI sister                    v=+0.832 a=-0.352 d=+0.124  -> v_used=+0.832
# UNI without                   v=-0.500 a=-0.370 d=-0.500  -> v_used=-0.500
# UNI wish                      v=+0.542 a=+0.166 d=+0.294  -> v_used=+0.542
# UNI that                      v=+0.000 a=+0.077 d=+0.000  -> v_used=+0.000
# UNI might                     v=+0.143 a=+0.963 d=+1.000  -> v_used=+0.143
# UNI become                    v=+0.282 a=+0.166 d=+0.286  -> v_used=+0.282
# UNI your                      v=+0.000 a=+0.000 d=+0.259  -> v_used=+0.000
# UNI wife                      v=+0.772 a=+0.260 d=+0.166  -> v_used=+0.772
# UNI nay                       v=-0.312 a=-0.420 d=-0.350  -> v_used=-0.312
# UNI may                       v=+0.408 a=-0.454 d=-0.510  -> v_used=+0.408
# UNI have                      v=+0.514 a=-0.222 d=+0.186  -> v_used=+0.514
# UNI met                       v=+0.358 a=-0.276 d=-0.160  -> v_used=+0.358
# UNI with                      v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI another                   v=-0.100 a=-0.318 d=+0.000  -> v_used=-0.100
# UNI whom                      v=-0.344 a=-0.048 d=-0.234  -> v_used=-0.344
# UNI may                       v=+0.408 a=-0.454 d=-0.510  -> v_used=+0.408
# UNI love                      v=+0.996 a=+0.334 d=+0.234  -> v_used=+0.996
# UNI and                       v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI yourself                  v=+0.354 a=-0.358 d=+0.210  -> v_used=+0.354
# UNI as                        v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI bound                     v=-0.166 a=+0.334 d=-0.380  -> v_used=-0.166
# UNI to                        v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI this                      v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI struggle                  v=-0.270 a=+0.640 d=+0.482  -> v_used=-0.270
# UNI may                       v=+0.408 a=-0.454 d=-0.510  -> v_used=+0.408
# UNI occasion                  v=+0.400 a=-0.098 d=-0.204  -> v_used=+0.400
# UNI poignant                  v=+0.292 a=-0.112 d=+0.036  -> v_used=+0.292
# UNI misery                    v=-0.708 a=-0.244 d=-0.684  -> v_used=-0.708
# UNI which                     v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI appear                    v=+0.470 a=+0.012 d=+0.134  -> v_used=+0.470
# UNI to                        v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI feel                      v=+0.604 a=+0.204 d=+0.192  -> v_used=+0.604
# UNI dear                      v=+0.760 a=-0.132 d=+0.258  -> v_used=+0.760
# UNI father                    v=+0.624 a=-0.334 d=+0.648  -> v_used=+0.624
# UNI reassure                  v=+0.674 a=-0.388 d=+0.260  -> v_used=+0.674
# UNI yourself                  v=+0.354 a=-0.358 d=+0.210  -> v_used=+0.354
# UNI love                      v=+0.996 a=+0.334 d=+0.234  -> v_used=+0.996
# UNI cousin                    v=+0.350 a=-0.212 d=-0.146  -> v_used=+0.350
# UNI tenderly                  v=+1.000 a=-0.708 d=-0.600  -> v_used=+1.000
# UNI and                       v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI saw                       v=-0.368 a=+0.082 d=+0.036  -> v_used=+0.368 [NEG]
# UNI excited                   v=+0.816 a=+0.862 d=+0.418  -> v_used=+0.816
# UNI as                        v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI admiration                v=+0.938 a=+0.166 d=+0.452  -> v_used=+0.938
# UNI and                       v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI affection                 v=+0.796 a=+0.118 d=+0.392  -> v_used=+0.796
# UNI future                    v=+0.776 a=+0.288 d=+0.572  -> v_used=+0.776
# UNI hopes                     v=+0.834 a=+0.000 d=+0.404  -> v_used=+0.834
# UNI and                       v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI are                       v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI entirely                  v=+0.000 a=+0.000 d=+0.037  -> v_used=+0.000
# UNI bound                     v=-0.166 a=+0.334 d=-0.380  -> v_used=-0.166
# UNI up                        v=+0.630 a=+0.792 d=+0.556  -> v_used=+0.630
# UNI expectation               v=+0.542 a=+0.380 d=+0.414  -> v_used=+0.542
# UNI of                        v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI our                       v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI union                     v=+0.708 a=-0.548 d=+0.532  -> v_used=+0.708
# UNI expression                v=+0.580 a=+0.300 d=+0.442  -> v_used=+0.580
# UNI of                        v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI your                      v=+0.000 a=+0.000 d=+0.259  -> v_used=+0.000
# UNI of                        v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI this                      v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI subject                   v=+0.204 a=-0.312 d=+0.116  -> v_used=+0.204
# UNI dear                      v=+0.760 a=-0.132 d=+0.258  -> v_used=+0.760
# UNI victor                    v=+0.604 a=+0.174 d=+0.592  -> v_used=+0.604
# UNI more                      v=+0.667 a=+0.000 d=+0.708  -> v_used=+0.667
# UNI pleasure                  v=+0.878 a=+0.480 d=+0.364  -> v_used=+0.878
# UNI have                      v=+0.514 a=-0.222 d=+0.186  -> v_used=+0.514
# UNI for                       v=+0.000 a=+0.000 d=+0.042  -> v_used=+0.000
# MWE some time                 v=+0.000 a=-0.250 d=-0.056  -> v_used=+0.000
# UNI experienced               v=+0.542 a=+0.226 d=+0.778  -> v_used=+0.542
#
# Aggregate: v=+0.290 a=-0.010 d=+0.108 | hits=75 / tokens=111 coverage=0.676 | MWE%=1%
#
# === Frankenstein.clean | chunk 153 ===
# such powerful protection. They consulted their village priest, and the result was that Elizabeth
# Lavenza became the inmate of my parents' house—my more than sister—the beautiful and adored
# companion of all my occupations and my pleasures. Everyone loved Elizabeth. The passionate and
# almost reverential attachment with which all regarded her became, while I shared it, my pride and my
# delight. On the evening previous to her being brought to my home, my mother had said playfully, "I
# have a pretty present for my Victor—tomorrow he shall have it."
#
# -- matches --
# UNI such                      v=+0.000 a=+0.111 d=+0.000  -> v_used=+0.000
# UNI powerful                  v=+0.566 a=+0.660 d=+0.991  -> v_used=+0.566
# UNI protection                v=+0.726 a=+0.060 d=+0.328  -> v_used=+0.726
# UNI they                      v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI their                     v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI village                   v=+0.368 a=-0.266 d=-0.328  -> v_used=+0.368
# UNI priest                    v=+0.122 a=-0.352 d=+0.296  -> v_used=+0.122
# UNI and                       v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI result                    v=+0.624 a=-0.020 d=+0.304  -> v_used=+0.624
# UNI was                       v=+0.000 a=-0.083 d=+0.000  -> v_used=+0.000
# UNI that                      v=+0.000 a=+0.077 d=+0.000  -> v_used=+0.000
# UNI became                    v=+0.000 a=+0.389 d=+0.000  -> v_used=+0.000
# UNI inmate                    v=-0.530 a=+0.326 d=-0.204  -> v_used=-0.530
# UNI of                        v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI house                     v=+0.174 a=-0.730 d=+0.066  -> v_used=+0.174
# MWE more than                 v=+0.192 a=-0.148 d=+0.200  -> v_used=+0.192
# UNI sister                    v=+0.832 a=-0.352 d=+0.124  -> v_used=+0.832
# UNI beautiful                 v=+0.750 a=+0.228 d=+0.296  -> v_used=+0.750
# UNI and                       v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI adored                    v=+1.000 a=-0.667 d=-0.148  -> v_used=+1.000
# UNI companion                 v=+0.540 a=-0.246 d=+0.236  -> v_used=+0.540
# UNI of                        v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI all                       v=+0.000 a=+0.000 d=+0.407  -> v_used=+0.000
# UNI and                       v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI pleasures                 v=+0.792 a=+0.308 d=+0.410  -> v_used=+0.792
# UNI everyone                  v=+0.200 a=-0.184 d=+0.038  -> v_used=+0.200
# UNI loved                     v=+0.854 a=-0.096 d=+0.164  -> v_used=+0.854
# UNI passionate                v=+0.990 a=+0.448 d=+0.498  -> v_used=+0.990
# UNI and                       v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI almost                    v=-0.072 a=-0.258 d=+0.032  -> v_used=-0.072
# UNI reverential               v=+0.600 a=-0.667 d=+0.111  -> v_used=+0.600
# UNI attachment                v=+0.140 a=-0.314 d=+0.000  -> v_used=+0.140
# UNI with                      v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI which                     v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI all                       v=+0.000 a=+0.000 d=+0.407  -> v_used=+0.000
# UNI became                    v=+0.000 a=+0.389 d=+0.000  -> v_used=+0.000
# UNI while                     v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI shared                    v=+0.667 a=+0.000 d=+0.444  -> v_used=+0.667
# UNI it                        v=+0.000 a=-0.282 d=+0.000  -> v_used=+0.000
# UNI pride                     v=+0.458 a=+0.268 d=+0.696  -> v_used=+0.458
# UNI and                       v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI delight                   v=+0.898 a=+0.332 d=+0.294  -> v_used=+0.898
# UNI on                        v=+0.000 a=+0.000 d=+0.056  -> v_used=+0.000
# UNI evening                   v=-0.084 a=-0.630 d=-0.364  -> v_used=-0.084
# UNI previous                  v=+0.042 a=-0.326 d=-0.304  -> v_used=+0.042
# UNI to                        v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI brought                   v=+0.104 a=-0.016 d=-0.172  -> v_used=+0.104
# UNI to                        v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI home                      v=+0.708 a=-0.460 d=+0.090  -> v_used=+0.708
# UNI mother                    v=+0.862 a=-0.184 d=+0.450  -> v_used=+0.862
# UNI playfully                 v=+0.917 a=+0.833 d=+0.333  -> v_used=+0.917
# UNI have                      v=+0.514 a=-0.222 d=+0.186  -> v_used=+0.514
# UNI pretty                    v=+0.750 a=+0.032 d=+0.122  -> v_used=+0.750
# UNI present                   v=+0.448 a=-0.428 d=+0.268  -> v_used=+0.448
# UNI for                       v=+0.000 a=+0.000 d=+0.042  -> v_used=+0.000
# UNI victor                    v=+0.604 a=+0.174 d=+0.592  -> v_used=+0.604
# UNI tomorrow                  v=+0.584 a=-0.246 d=-0.186  -> v_used=+0.584
# UNI he                        v=+0.611 a=+0.000 d=+0.556  -> v_used=+0.611
# UNI shall                     v=+0.020 a=-0.230 d=-0.176  -> v_used=+0.020
# MWE have it                   v=+0.188 a=-0.206 d=-0.104  -> v_used=+0.188
#
# Aggregate: v=+0.286 a=-0.050 d=+0.118 | hits=60 / tokens=89 coverage=0.674 | MWE%=3%
#       chunk_id         v         a         d  coverage
# 2666      2666 -0.121089  0.068244 -0.018244  0.714286
# 3958      3958 -0.103301  0.017452 -0.072425  0.634783
# === Mobi Dick.clean | chunk 2666 ===
# Starbuck was too late. At the instant of the dart an ulcerous jet shot from this cruel wound, and
# goaded by it into more than sufferable anguish, the whale now spouting thick blood, with swift fury
# blindly darted at the craft, bespattering them and their glorying crews all over with showers of
# gore, capsizing Flask's boat and marring the bows. It was his death stroke.
#
# -- matches --
# UNI was                       v=+0.000 a=-0.083 d=+0.000  -> v_used=+0.000
# UNI too                       v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI late                      v=-0.510 a=-0.284 d=-0.370  -> v_used=-0.510
# UNI at                        v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI instant                   v=+0.532 a=-0.092 d=+0.108  -> v_used=+0.532
# UNI of                        v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI dart                      v=-0.166 a=+0.216 d=+0.000  -> v_used=-0.166
# UNI ulcerous                  v=-1.000 a=+0.375 d=-0.625  -> v_used=-1.000
# UNI jet                       v=+0.224 a=+0.442 d=+0.212  -> v_used=+0.224
# UNI shot                      v=-0.712 a=+0.500 d=+0.138  -> v_used=-0.712
# UNI from                      v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI this                      v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI cruel                     v=-0.756 a=+0.732 d=-0.218  -> v_used=-0.756
# UNI wound                     v=-0.700 a=+0.434 d=-0.380  -> v_used=-0.700
# UNI and                       v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI by                        v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI it                        v=+0.000 a=-0.282 d=+0.000  -> v_used=+0.000
# UNI into                      v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# MWE more than                 v=+0.192 a=-0.148 d=+0.200  -> v_used=+0.192
# UNI sufferable                v=-0.375 a=-0.667 d=-0.208  -> v_used=-0.375
# UNI anguish                   v=-0.694 a=+0.584 d=-0.470  -> v_used=-0.694
# UNI whale                     v=+0.164 a=-0.204 d=+0.018  -> v_used=+0.164
# UNI now                       v=+0.226 a=-0.164 d=+0.032  -> v_used=+0.226
# UNI thick                     v=-0.102 a=-0.134 d=+0.192  -> v_used=-0.102
# UNI blood                     v=-0.562 a=+0.368 d=+0.170  -> v_used=-0.562
# UNI with                      v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI swift                     v=+0.451 a=+0.552 d=+0.396  -> v_used=+0.451
# UNI fury                      v=-0.876 a=+0.750 d=+0.352  -> v_used=-0.876
# UNI blindly                   v=-0.122 a=+0.196 d=-0.444  -> v_used=-0.122
# UNI at                        v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI craft                     v=+0.520 a=-0.358 d=+0.078  -> v_used=+0.520
# UNI them                      v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI and                       v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI their                     v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# MWE all over                  v=-0.032 a=-0.080 d=+0.214  -> v_used=-0.032
# UNI with                      v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI of                        v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI gore                      v=-0.480 a=+0.216 d=+0.036  -> v_used=-0.480
# UNI boat                      v=+0.032 a=-0.160 d=+0.108  -> v_used=+0.032
# UNI and                       v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI bows                      v=+0.111 a=+0.407 d=-0.444  -> v_used=+0.111
# UNI it                        v=+0.000 a=-0.282 d=+0.000  -> v_used=+0.000
# UNI was                       v=+0.000 a=-0.083 d=+0.000  -> v_used=+0.000
# UNI death                     v=-0.938 a=+0.440 d=-0.056  -> v_used=-0.938
# UNI stroke                    v=+0.124 a=-0.120 d=+0.140  -> v_used=+0.124
#
# Aggregate: v=-0.121 a=+0.068 d=-0.018 | hits=45 / tokens=63 coverage=0.714 | MWE%=4%
#
# === Mobi Dick.clean | chunk 3958 ===
# a widow with her husband alive! Aye, I widowed that poor girl when I married her, Starbuck; and
# then, the madness, the frenzy, the boiling blood and the smoking brow, with which, for a thousand
# lowerings old Ahab has furiously, foamingly chased his prey—more a demon than a man!—aye, aye! what
# a forty years' fool—fool—old fool, has old Ahab been! Why this strife of the chase? why weary, and
# palsy the arm at the oar, and the iron, and the lance? how the richer or better is Ahab now? Behold.
# Oh, Starbuck! is it not hard, that with this weary load I bear, one poor leg should have been
# snatched from under me?
#
# -- matches --
# UNI widow                     v=-0.500 a=-0.100 d=-0.470  -> v_used=-0.500
# UNI with                      v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI husband                   v=+0.542 a=+0.000 d=+0.310  -> v_used=+0.542
# UNI alive                     v=+0.511 a=+0.274 d=+0.462  -> v_used=+0.511
# UNI aye                       v=+0.124 a=-0.160 d=-0.216  -> v_used=+0.124
# UNI widowed                   v=-0.590 a=-0.122 d=-0.334  -> v_used=-0.590
# UNI that                      v=+0.000 a=+0.077 d=+0.000  -> v_used=+0.000
# UNI poor                      v=-0.688 a=-0.284 d=-0.869  -> v_used=-0.688
# UNI when                      v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI married                   v=+0.348 a=+0.140 d=+0.204  -> v_used=+0.348
# UNI and                       v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI then                      v=+0.000 a=+0.000 d=-0.048  -> v_used=+0.000
# UNI madness                   v=-0.792 a=+0.608 d=-0.120  -> v_used=-0.792
# UNI frenzy                    v=+0.220 a=+0.967 d=+0.199  -> v_used=+0.220
# UNI boiling                   v=-0.396 a=+0.380 d=+0.052  -> v_used=-0.396
# UNI blood                     v=-0.562 a=+0.368 d=+0.170  -> v_used=-0.562
# UNI and                       v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI smoking                   v=-0.648 a=+0.114 d=-0.232  -> v_used=-0.648
# UNI brow                      v=+0.124 a=-0.378 d=-0.038  -> v_used=+0.124
# UNI with                      v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI which                     v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI for                       v=+0.000 a=+0.000 d=+0.042  -> v_used=+0.000
# UNI thousand                  v=+0.326 a=-0.290 d=-0.040  -> v_used=+0.326
# UNI furiously                 v=-0.876 a=+0.850 d=+0.314  -> v_used=-0.876
# UNI chased                    v=-0.624 a=+0.660 d=-0.426  -> v_used=-0.624
# UNI prey                      v=-0.244 a=+0.000 d=-0.388  -> v_used=-0.244
# UNI more                      v=+0.667 a=+0.000 d=+0.708  -> v_used=+0.667
# UNI demon                     v=-0.926 a=+0.816 d=+0.018  -> v_used=-0.926
# MWE aye aye                   v=-0.080 a=+0.060 d=-0.234  -> v_used=-0.080
# UNI what                      v=+0.000 a=+0.046 d=+0.000  -> v_used=+0.000
# UNI forty                     v=-0.084 a=-0.266 d=-0.036  -> v_used=-0.084
# UNI years                     v=+0.306 a=-0.340 d=+0.016  -> v_used=+0.306
# UNI fool                      v=-0.680 a=+0.120 d=-0.704  -> v_used=-0.680
# UNI fool                      v=-0.680 a=+0.120 d=-0.704  -> v_used=-0.680
# UNI fool                      v=-0.680 a=+0.120 d=-0.704  -> v_used=-0.680
# UNI been                      v=+0.000 a=-0.704 d=+0.000  -> v_used=+0.000
# UNI why                       v=+0.000 a=+0.667 d=-0.286  -> v_used=+0.000
# UNI this                      v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI strife                    v=-0.312 a=+0.796 d=+0.260  -> v_used=-0.312
# UNI of                        v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI chase                     v=-0.208 a=+0.756 d=+0.246  -> v_used=-0.208
# UNI why                       v=+0.000 a=+0.667 d=-0.286  -> v_used=+0.000
# UNI weary                     v=-0.612 a=-0.438 d=-0.596  -> v_used=-0.612
# UNI and                       v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI palsy                     v=-0.834 a=-0.108 d=-0.558  -> v_used=-0.834
# UNI arm                       v=+0.104 a=-0.430 d=-0.062  -> v_used=+0.104
# UNI at                        v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI oar                       v=-0.062 a=-0.216 d=-0.368  -> v_used=-0.062
# UNI and                       v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI iron                      v=-0.104 a=-0.298 d=+0.358  -> v_used=-0.104
# UNI and                       v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI lance                     v=-0.188 a=+0.240 d=+0.174  -> v_used=-0.188
# UNI how                       v=+0.000 a=+0.000 d=+0.296  -> v_used=+0.000
# UNI better                    v=+0.778 a=+0.074 d=+0.714  -> v_used=+0.778
# UNI is                        v=+0.000 a=+0.000 d=+0.048  -> v_used=+0.000
# UNI now                       v=+0.226 a=-0.164 d=+0.032  -> v_used=+0.226
# UNI behold                    v=+0.220 a=-0.432 d=-0.102  -> v_used=+0.220
# MWE is it                     v=-0.130 a=-0.278 d=-0.414  -> v_used=-0.130
# UNI hard                      v=-0.396 a=+0.416 d=+0.232  -> v_used=+0.396 [NEG]
# UNI that                      v=+0.000 a=+0.077 d=+0.000  -> v_used=-0.000 [NEG]
# UNI with                      v=+0.000 a=+0.000 d=+0.000  -> v_used=-0.000 [NEG]
# UNI this                      v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI weary                     v=-0.612 a=-0.438 d=-0.596  -> v_used=-0.612
# UNI load                      v=-0.230 a=-0.166 d=+0.056  -> v_used=-0.230
# UNI bear                      v=-0.104 a=+0.140 d=-0.050  -> v_used=-0.104
# UNI one                       v=+0.084 a=-0.416 d=-0.260  -> v_used=+0.084
# UNI poor                      v=-0.688 a=-0.284 d=-0.869  -> v_used=-0.688
# UNI leg                       v=+0.020 a=-0.254 d=-0.374  -> v_used=+0.020
# UNI should                    v=+0.083 a=-0.037 d=+0.500  -> v_used=+0.083
# UNI have                      v=+0.514 a=-0.222 d=+0.186  -> v_used=+0.514
# UNI been                      v=+0.000 a=-0.704 d=+0.000  -> v_used=+0.000
# UNI from                      v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI under                     v=+0.000 a=-0.750 d=-0.500  -> v_used=+0.000
#
# Aggregate: v=-0.103 a=+0.017 d=-0.072 | hits=73 / tokens=115 coverage=0.635 | MWE%=3%
#     chunk_id         v         a         d  coverage
# 1          1  0.186459 -0.256525  0.110180  0.521368
# 2          2  0.195841 -0.127683  0.045127  0.538462
# 40        40  0.113000 -0.091792 -0.019271  0.539326
# === Romeo and Juliet.clean | chunk 1 ===
# VI. Friar Lawrence's Cell. ACT III Scene I. A public Place. Scene II. A Room in Capulet's House.
# Scene III. Friar Lawrence's cell. Scene IV. A Room in Capulet's House. Scene V. An open Gallery to
# Juliet's Chamber, overlooking the Garden. ACT IV Scene I. Friar Lawrence's Cell. Scene II. Hall in
# Capulet's House. Scene III. Juliet's Chamber. Scene IV. Hall in Capulet's House. Scene V. Juliet's
# Chamber; Juliet on the bed. ACT V Scene I. Mantua. A Street. Scene II. Friar Lawrence's Cell. Scene
# III. A churchyard; in it a Monument belonging to the Capulets. Dramatis Personæ ESCALUS, Prince of
# Verona. MERCUTIO, kinsman to the Prince, and friend to Romeo. PARIS, a young Nobleman, kinsman to
# the Prince.
#
# -- matches --
# UNI friar                     v=+0.020 a=-0.480 d=+0.062  -> v_used=+0.020
# UNI cell                      v=+0.082 a=-0.250 d=-0.070  -> v_used=+0.082
# UNI act                       v=+0.312 a=+0.408 d=+0.470  -> v_used=+0.312
# UNI scene                     v=+0.140 a=-0.320 d=+0.156  -> v_used=+0.140
# UNI public                    v=+0.184 a=+0.020 d=+0.328  -> v_used=+0.184
# UNI place                     v=+0.146 a=-0.478 d=-0.204  -> v_used=+0.146
# UNI scene                     v=+0.140 a=-0.320 d=+0.156  -> v_used=+0.140
# MWE room in                   v=+0.000 a=-0.224 d=+0.172  -> v_used=+0.000
# UNI house                     v=+0.174 a=-0.730 d=+0.066  -> v_used=+0.174
# UNI scene                     v=+0.140 a=-0.320 d=+0.156  -> v_used=+0.140
# UNI friar                     v=+0.020 a=-0.480 d=+0.062  -> v_used=+0.020
# UNI cell                      v=+0.082 a=-0.250 d=-0.070  -> v_used=+0.082
# UNI scene                     v=+0.140 a=-0.320 d=+0.156  -> v_used=+0.140
# MWE room in                   v=+0.000 a=-0.224 d=+0.172  -> v_used=+0.000
# UNI house                     v=+0.174 a=-0.730 d=+0.066  -> v_used=+0.174
# UNI scene                     v=+0.140 a=-0.320 d=+0.156  -> v_used=+0.140
# UNI open                      v=+0.240 a=-0.040 d=+0.138  -> v_used=+0.240
# UNI gallery                   v=+0.318 a=-0.134 d=+0.138  -> v_used=+0.318
# UNI to                        v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI chamber                   v=+0.166 a=-0.254 d=-0.090  -> v_used=+0.166
# UNI garden                    v=+0.540 a=-0.540 d=-0.088  -> v_used=+0.540
# UNI act                       v=+0.312 a=+0.408 d=+0.470  -> v_used=+0.312
# UNI scene                     v=+0.140 a=-0.320 d=+0.156  -> v_used=+0.140
# UNI friar                     v=+0.020 a=-0.480 d=+0.062  -> v_used=+0.020
# UNI cell                      v=+0.082 a=-0.250 d=-0.070  -> v_used=+0.082
# UNI scene                     v=+0.140 a=-0.320 d=+0.156  -> v_used=+0.140
# UNI hall                      v=+0.020 a=-0.320 d=-0.152  -> v_used=+0.020
# UNI house                     v=+0.174 a=-0.730 d=+0.066  -> v_used=+0.174
# UNI scene                     v=+0.140 a=-0.320 d=+0.156  -> v_used=+0.140
# UNI chamber                   v=+0.166 a=-0.254 d=-0.090  -> v_used=+0.166
# UNI scene                     v=+0.140 a=-0.320 d=+0.156  -> v_used=+0.140
# UNI hall                      v=+0.020 a=-0.320 d=-0.152  -> v_used=+0.020
# UNI house                     v=+0.174 a=-0.730 d=+0.066  -> v_used=+0.174
# UNI scene                     v=+0.140 a=-0.320 d=+0.156  -> v_used=+0.140
# UNI chamber                   v=+0.166 a=-0.254 d=-0.090  -> v_used=+0.166
# UNI on                        v=+0.000 a=+0.000 d=+0.056  -> v_used=+0.000
# UNI bed                       v=+0.208 a=-0.654 d=-0.346  -> v_used=+0.208
# UNI act                       v=+0.312 a=+0.408 d=+0.470  -> v_used=+0.312
# UNI scene                     v=+0.140 a=-0.320 d=+0.156  -> v_used=+0.140
# UNI street                    v=+0.188 a=-0.352 d=-0.204  -> v_used=+0.188
# UNI scene                     v=+0.140 a=-0.320 d=+0.156  -> v_used=+0.140
# UNI friar                     v=+0.020 a=-0.480 d=+0.062  -> v_used=+0.020
# UNI cell                      v=+0.082 a=-0.250 d=-0.070  -> v_used=+0.082
# UNI scene                     v=+0.140 a=-0.320 d=+0.156  -> v_used=+0.140
# UNI churchyard                v=-0.408 a=-0.112 d=-0.306  -> v_used=-0.408
# UNI it                        v=+0.000 a=-0.282 d=+0.000  -> v_used=+0.000
# UNI monument                  v=+0.666 a=-0.192 d=+0.645  -> v_used=+0.666
# UNI to                        v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI person                    v=+0.292 a=-0.274 d=+0.192  -> v_used=+0.292
# UNI prince                    v=+0.776 a=-0.072 d=+0.740  -> v_used=+0.776
# UNI of                        v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI kinsman                   v=+0.556 a=-0.583 d=+0.074  -> v_used=+0.556
# UNI to                        v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI prince                    v=+0.776 a=-0.072 d=+0.740  -> v_used=+0.776
# UNI and                       v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI friend                    v=+0.812 a=-0.174 d=+0.146  -> v_used=+0.812
# UNI to                        v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI nobleman                  v=+0.350 a=-0.428 d=+0.418  -> v_used=+0.350
# UNI kinsman                   v=+0.556 a=-0.583 d=+0.074  -> v_used=+0.556
# UNI to                        v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI prince                    v=+0.776 a=-0.072 d=+0.740  -> v_used=+0.776
#
# Aggregate: v=+0.186 a=-0.257 d=+0.110 | hits=61 / tokens=117 coverage=0.521 | MWE%=3%
#
# -- per sentence --
# [s01] v=None a=None d=None (cov=0.00) :: VI.
# [s02] v=0.051 a=-0.365 d=-0.004 (cov=0.67) :: Friar Lawrence's Cell.
# [s03] v=0.226 a=0.044 d=0.313 (cov=0.50) :: ACT III Scene I.
# [s04] v=0.165 a=-0.229 d=0.062 (cov=0.67) :: A public Place.
# [s05] v=0.14 a=-0.32 d=0.156 (cov=0.50) :: Scene II.
# [s06] v=0.087 a=-0.477 d=0.119 (cov=0.50) :: A Room in Capulet's House.
# [s07] v=0.14 a=-0.32 d=0.156 (cov=0.50) :: Scene III.
# [s08] v=0.051 a=-0.365 d=-0.004 (cov=0.67) :: Friar Lawrence's cell.
# [s09] v=0.14 a=-0.32 d=0.156 (cov=0.50) :: Scene IV.
# [s10] v=0.087 a=-0.477 d=0.119 (cov=0.50) :: A Room in Capulet's House.
# [s11] v=0.14 a=-0.32 d=0.156 (cov=0.50) :: Scene V.
# [s12] v=0.253 a=-0.194 d=0.02 (cov=0.56) :: An open Gallery to Juliet's Chamber, overlooking the Garden.
# [s13] v=0.226 a=0.044 d=0.313 (cov=0.50) :: ACT IV Scene I.
# [s14] v=0.051 a=-0.365 d=-0.004 (cov=0.67) :: Friar Lawrence's Cell.
# [s15] v=0.14 a=-0.32 d=0.156 (cov=0.50) :: Scene II.
# [s16] v=0.097 a=-0.525 d=-0.043 (cov=0.50) :: Hall in Capulet's House.
# [s17] v=0.14 a=-0.32 d=0.156 (cov=0.50) :: Scene III.
# [s18] v=0.166 a=-0.254 d=-0.09 (cov=0.50) :: Juliet's Chamber.
# [s19] v=0.14 a=-0.32 d=0.156 (cov=0.50) :: Scene IV.
# [s20] v=0.097 a=-0.525 d=-0.043 (cov=0.50) :: Hall in Capulet's House.
# [s21] v=0.14 a=-0.32 d=0.156 (cov=0.50) :: Scene V.
# [s22] v=0.125 a=-0.303 d=-0.127 (cov=0.50) :: Juliet's Chamber; Juliet on the bed.
# [s23] v=0.226 a=0.044 d=0.313 (cov=0.50) :: ACT V Scene I.
# [s24] v=None a=None d=None (cov=0.00) :: Mantua.
# [s25] v=0.188 a=-0.352 d=-0.204 (cov=0.50) :: A Street.
# [s26] v=0.14 a=-0.32 d=0.156 (cov=0.50) :: Scene II.
# [s27] v=0.051 a=-0.365 d=-0.004 (cov=0.67) :: Friar Lawrence's Cell.
# [s28] v=0.14 a=-0.32 d=0.156 (cov=0.50) :: Scene III.
# [s29] v=0.065 a=-0.146 d=0.085 (cov=0.40) :: A churchyard; in it a Monument belonging to the Capulets.
# [s30] v=0.356 a=-0.115 d=0.311 (cov=0.50) :: Dramatis Personæ ESCALUS, Prince of Verona.
# [s31] v=0.357 a=-0.138 d=0.16 (cov=0.67) :: MERCUTIO, kinsman to the Prince, and friend to Romeo.
# [s32] v=0.42 a=-0.271 d=0.308 (cov=0.50) :: PARIS, a young Nobleman, kinsman to the Prince.
#
# === Romeo and Juliet.clean | chunk 2 ===
# IV. Hall in Capulet's House. Scene V. Juliet's Chamber; Juliet on the bed. ACT V Scene I. Mantua. A
# Street. Scene II. Friar Lawrence's Cell. Scene III. A churchyard; in it a Monument belonging to the
# Capulets. Dramatis Personæ ESCALUS, Prince of Verona. MERCUTIO, kinsman to the Prince, and friend to
# Romeo. PARIS, a young Nobleman, kinsman to the Prince. Page to Paris. MONTAGUE, head of a Veronese
# family at feud with the Capulets. LADY MONTAGUE, wife to Montague. ROMEO, son to Montague. BENVOLIO,
# nephew to Montague, and friend to Romeo. ABRAM, servant to Montague. BALTHASAR, servant to Romeo.
# CAPULET, head of a Veronese family at feud with the Montagues. LADY CAPULET, wife to Capulet.
# JULIET, daughter to Capulet.
#
# -- matches --
# UNI hall                      v=+0.020 a=-0.320 d=-0.152  -> v_used=+0.020
# UNI house                     v=+0.174 a=-0.730 d=+0.066  -> v_used=+0.174
# UNI scene                     v=+0.140 a=-0.320 d=+0.156  -> v_used=+0.140
# UNI chamber                   v=+0.166 a=-0.254 d=-0.090  -> v_used=+0.166
# UNI on                        v=+0.000 a=+0.000 d=+0.056  -> v_used=+0.000
# UNI bed                       v=+0.208 a=-0.654 d=-0.346  -> v_used=+0.208
# UNI act                       v=+0.312 a=+0.408 d=+0.470  -> v_used=+0.312
# UNI scene                     v=+0.140 a=-0.320 d=+0.156  -> v_used=+0.140
# UNI street                    v=+0.188 a=-0.352 d=-0.204  -> v_used=+0.188
# UNI scene                     v=+0.140 a=-0.320 d=+0.156  -> v_used=+0.140
# UNI friar                     v=+0.020 a=-0.480 d=+0.062  -> v_used=+0.020
# UNI cell                      v=+0.082 a=-0.250 d=-0.070  -> v_used=+0.082
# UNI scene                     v=+0.140 a=-0.320 d=+0.156  -> v_used=+0.140
# UNI churchyard                v=-0.408 a=-0.112 d=-0.306  -> v_used=-0.408
# UNI it                        v=+0.000 a=-0.282 d=+0.000  -> v_used=+0.000
# UNI monument                  v=+0.666 a=-0.192 d=+0.645  -> v_used=+0.666
# UNI to                        v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI person                    v=+0.292 a=-0.274 d=+0.192  -> v_used=+0.292
# UNI prince                    v=+0.776 a=-0.072 d=+0.740  -> v_used=+0.776
# UNI of                        v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI kinsman                   v=+0.556 a=-0.583 d=+0.074  -> v_used=+0.556
# UNI to                        v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI prince                    v=+0.776 a=-0.072 d=+0.740  -> v_used=+0.776
# UNI and                       v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI friend                    v=+0.812 a=-0.174 d=+0.146  -> v_used=+0.812
# UNI to                        v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI nobleman                  v=+0.350 a=-0.428 d=+0.418  -> v_used=+0.350
# UNI kinsman                   v=+0.556 a=-0.583 d=+0.074  -> v_used=+0.556
# UNI to                        v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI prince                    v=+0.776 a=-0.072 d=+0.740  -> v_used=+0.776
# UNI page                      v=+0.354 a=-0.552 d=-0.444  -> v_used=+0.354
# UNI to                        v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI head                      v=+0.060 a=-0.056 d=+0.116  -> v_used=+0.060
# MWE of a                      v=-0.222 a=-0.238 d=-0.322  -> v_used=-0.222
# UNI family                    v=+0.936 a=-0.234 d=+0.286  -> v_used=+0.936
# UNI at                        v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI feud                      v=-0.708 a=+0.592 d=-0.376  -> v_used=-0.708
# UNI with                      v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI lady                      v=+0.708 a=-0.038 d=+0.204  -> v_used=+0.708
# UNI wife                      v=+0.772 a=+0.260 d=+0.166  -> v_used=+0.772
# UNI to                        v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI son                       v=+0.584 a=-0.270 d=+0.056  -> v_used=+0.584
# UNI to                        v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI nephew                    v=+0.438 a=-0.326 d=-0.176  -> v_used=+0.438
# UNI to                        v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI and                       v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI friend                    v=+0.812 a=-0.174 d=+0.146  -> v_used=+0.812
# UNI to                        v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI servant                   v=-0.320 a=-0.184 d=-0.338  -> v_used=-0.320
# UNI to                        v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI servant                   v=-0.320 a=-0.184 d=-0.338  -> v_used=-0.320
# UNI to                        v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI head                      v=+0.060 a=-0.056 d=+0.116  -> v_used=+0.060
# MWE of a                      v=-0.222 a=-0.238 d=-0.322  -> v_used=-0.222
# UNI family                    v=+0.936 a=-0.234 d=+0.286  -> v_used=+0.936
# UNI at                        v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI feud                      v=-0.708 a=+0.592 d=-0.376  -> v_used=-0.708
# UNI with                      v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI lady                      v=+0.708 a=-0.038 d=+0.204  -> v_used=+0.708
# UNI wife                      v=+0.772 a=+0.260 d=+0.166  -> v_used=+0.772
# UNI to                        v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI daughter                  v=+0.816 a=-0.170 d=-0.090  -> v_used=+0.816
# UNI to                        v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
#
# Aggregate: v=+0.196 a=-0.128 d=+0.045 | hits=63 / tokens=117 coverage=0.538 | MWE%=3%
#
# -- per sentence --
# [s01] v=None a=None d=None (cov=0.00) :: IV.
# [s02] v=0.097 a=-0.525 d=-0.043 (cov=0.50) :: Hall in Capulet's House.
# [s03] v=0.14 a=-0.32 d=0.156 (cov=0.50) :: Scene V.
# [s04] v=0.125 a=-0.303 d=-0.127 (cov=0.50) :: Juliet's Chamber; Juliet on the bed.
# [s05] v=0.226 a=0.044 d=0.313 (cov=0.50) :: ACT V Scene I.
# [s06] v=None a=None d=None (cov=0.00) :: Mantua.
# [s07] v=0.188 a=-0.352 d=-0.204 (cov=0.50) :: A Street.
# [s08] v=0.14 a=-0.32 d=0.156 (cov=0.50) :: Scene II.
# [s09] v=0.051 a=-0.365 d=-0.004 (cov=0.67) :: Friar Lawrence's Cell.
# [s10] v=0.14 a=-0.32 d=0.156 (cov=0.50) :: Scene III.
# [s11] v=0.065 a=-0.146 d=0.085 (cov=0.40) :: A churchyard; in it a Monument belonging to the Capulets.
# [s12] v=0.356 a=-0.115 d=0.311 (cov=0.50) :: Dramatis Personæ ESCALUS, Prince of Verona.
# [s13] v=0.357 a=-0.138 d=0.16 (cov=0.67) :: MERCUTIO, kinsman to the Prince, and friend to Romeo.
# [s14] v=0.42 a=-0.271 d=0.308 (cov=0.50) :: PARIS, a young Nobleman, kinsman to the Prince.
# [s15] v=0.177 a=-0.276 d=-0.222 (cov=0.67) :: Page to Paris.
# [s16] v=0.011 a=0.011 d=-0.049 (cov=0.60) :: MONTAGUE, head of a Veronese family at feud with the Capulets.
# [s17] v=0.493 a=0.074 d=0.123 (cov=0.60) :: LADY MONTAGUE, wife to Montague.
# [s18] v=0.292 a=-0.135 d=0.028 (cov=0.50) :: ROMEO, son to Montague.
# [s19] v=0.25 a=-0.1 d=-0.006 (cov=0.62) :: BENVOLIO, nephew to Montague, and friend to Romeo.
# [s20] v=-0.16 a=-0.092 d=-0.169 (cov=0.50) :: ABRAM, servant to Montague.
# [s21] v=-0.16 a=-0.092 d=-0.169 (cov=0.50) :: BALTHASAR, servant to Romeo.
# [s22] v=0.011 a=0.011 d=-0.049 (cov=0.60) :: CAPULET, head of a Veronese family at feud with the Montagues.
# [s23] v=0.493 a=0.074 d=0.123 (cov=0.60) :: LADY CAPULET, wife to Capulet.
# [s24] v=0.408 a=-0.085 d=-0.045 (cov=0.50) :: JULIET, daughter to Capulet.
#
# === Romeo and Juliet.clean | chunk 40 ===
# who. ROMEO. Bid a sick man in sadness make his will, A word ill urg'd to one that is so ill. In
# sadness, cousin, I do love a woman. BENVOLIO. I aim'd so near when I suppos'd you lov'd. ROMEO. A
# right good markman, and she's fair I love. BENVOLIO. A right fair mark, fair coz, is soonest hit.
# ROMEO. Well, in that hit you miss: she'll not be hit With Cupid's arrow, she hath Dian's wit; And in
# strong proof of chastity well arm'd, From love's weak childish bow she lives uncharm'd.
#
# -- matches --
# UNI bid                       v=+0.520 a=+0.060 d=+0.310  -> v_used=+0.520
# MWE sick man                  v=-0.566 a=-0.300 d=-0.608  -> v_used=-0.566
# UNI sadness                   v=-0.896 a=-0.424 d=-0.672  -> v_used=-0.896
# UNI make                      v=+0.368 a=-0.160 d=-0.040  -> v_used=+0.368
# UNI will                      v=+0.396 a=-0.184 d=+0.470  -> v_used=+0.396
# UNI word                      v=+0.104 a=-0.490 d=-0.036  -> v_used=+0.104
# UNI ill                       v=-0.854 a=-0.180 d=-0.600  -> v_used=-0.854
# UNI to                        v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI one                       v=+0.084 a=-0.416 d=-0.260  -> v_used=+0.084
# MWE that is                   v=-0.194 a=-0.268 d=+0.038  -> v_used=-0.194
# UNI ill                       v=-0.854 a=-0.180 d=-0.600  -> v_used=-0.854
# UNI sadness                   v=-0.896 a=-0.424 d=-0.672  -> v_used=-0.896
# UNI cousin                    v=+0.350 a=-0.212 d=-0.146  -> v_used=+0.350
# UNI do                        v=+0.340 a=+0.096 d=+0.072  -> v_used=+0.340
# UNI love                      v=+0.996 a=+0.334 d=+0.234  -> v_used=+0.996
# UNI near                      v=+0.148 a=-0.246 d=-0.270  -> v_used=+0.148
# UNI when                      v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI right                     v=+0.480 a=-0.296 d=+0.420  -> v_used=+0.480
# UNI good                      v=+0.876 a=-0.264 d=+0.068  -> v_used=+0.876
# UNI and                       v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI fair                      v=+0.624 a=+0.114 d=+0.286  -> v_used=+0.624
# UNI love                      v=+0.996 a=+0.334 d=+0.234  -> v_used=+0.996
# UNI right                     v=+0.480 a=-0.296 d=+0.420  -> v_used=+0.480
# UNI fair                      v=+0.624 a=+0.114 d=+0.286  -> v_used=+0.624
# UNI mark                      v=-0.018 a=-0.538 d=+0.200  -> v_used=-0.018
# UNI fair                      v=+0.624 a=+0.114 d=+0.286  -> v_used=+0.624
# UNI coz                       v=-0.322 a=-0.276 d=-0.406  -> v_used=-0.322
# UNI is                        v=+0.000 a=+0.000 d=+0.048  -> v_used=+0.000
# UNI hit                       v=-0.530 a=+0.862 d=+0.358  -> v_used=-0.530
# UNI well                      v=+1.000 a=-0.259 d=+0.148  -> v_used=+1.000
# MWE in that                   v=+0.034 a=-0.254 d=-0.344  -> v_used=+0.034
# UNI hit                       v=-0.530 a=+0.862 d=+0.358  -> v_used=-0.530
# UNI miss                      v=+0.146 a=-0.020 d=-0.184  -> v_used=+0.146
# UNI be                        v=+0.340 a=-0.520 d=+0.108  -> v_used=-0.340 [NEG]
# MWE hit with                  v=-0.464 a=+0.152 d=-0.404  -> v_used=+0.464 [NEG]
# UNI arrow                     v=-0.122 a=-0.220 d=-0.092  -> v_used=-0.122
# UNI hath                      v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI wit                       v=+0.688 a=-0.032 d=+0.550  -> v_used=+0.688
# UNI and                       v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI strong                    v=+0.824 a=+0.490 d=+0.790  -> v_used=+0.824
# UNI proof                     v=-0.124 a=+0.018 d=+0.238  -> v_used=-0.124
# UNI of                        v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI chastity                  v=-0.062 a=-0.216 d=+0.018  -> v_used=-0.062
# UNI well                      v=+1.000 a=-0.259 d=+0.148  -> v_used=+1.000
# UNI from                      v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI weak                      v=-0.640 a=-0.518 d=-0.955  -> v_used=-0.640
# UNI childish                  v=+0.146 a=-0.116 d=-0.540  -> v_used=+0.146
# UNI bow                       v=+0.060 a=-0.388 d=-0.184  -> v_used=+0.060
#
# Aggregate: v=+0.113 a=-0.092 d=-0.019 | hits=48 / tokens=89 coverage=0.539 | MWE%=8%
#
# -- per sentence --
# [s01] v=None a=None d=None (cov=0.00) :: who.
# [s02] v=None a=None d=None (cov=0.00) :: ROMEO.
# [s03] v=-0.172 a=-0.231 d=-0.182 (cov=0.65) :: Bid a sick man in sadness make his will, A word ill urg'd to one that is so ill.
# [s04] v=0.198 a=-0.052 d=-0.128 (cov=0.50) :: In sadness, cousin, I do love a woman.
# [s05] v=None a=None d=None (cov=0.00) :: BENVOLIO.
# [s06] v=0.074 a=-0.123 d=-0.135 (cov=0.22) :: I aim'd so near when I suppos'd you lov'd.
# [s07] v=None a=None d=None (cov=0.00) :: ROMEO.
# [s08] v=0.595 a=-0.022 d=0.202 (cov=0.56) :: A right good markman, and she's fair I love.
# [s09] v=None a=None d=None (cov=0.00) :: BENVOLIO.
# [s10] v=0.123 a=-0.003 d=0.17 (cov=0.78) :: A right fair mark, fair coz, is soonest hit.
# [s11] v=None a=None d=None (cov=0.00) :: ROMEO.
# [s12] v=0.134 a=-0.067 d=-0.018 (cov=0.61) :: Well, in that hit you miss: she'll not be hit With Cupid's arrow, she hath Dian'...
#
# === Pride and Prejudice.clean | chunk 123 ===
# Mr. Bingley." "I am sick of Mr. Bingley," cried his wife. "I am sorry to hear _that_; but why did
# you not tell me so before? If I had known as much this morning, I certainly would not have called on
# him. It is very unlucky; but as I have actually paid the visit, we cannot escape the acquaintance
# now." The astonishment of the ladies was just what he wished--that of Mrs. Bennet perhaps surpassing
# the rest; though when the first tumult of joy was over, she began to declare that it was what she
# had expected all the while. "How good it was in you, my dear Mr. Bennet! But I knew I should
# persuade you at last.
#
# -- matches --
# UNI am                        v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# MWE sick of                   v=-0.656 a=-0.140 d=-0.310  -> v_used=-0.656
# UNI cried                     v=-0.666 a=+0.224 d=-0.492  -> v_used=-0.666
# UNI wife                      v=+0.772 a=+0.260 d=+0.166  -> v_used=+0.772
# UNI am                        v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI sorry                     v=-0.188 a=-0.276 d=-0.576  -> v_used=-0.188
# UNI to                        v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI hear                      v=+0.520 a=-0.142 d=-0.112  -> v_used=+0.520
# UNI that                      v=+0.000 a=+0.077 d=+0.000  -> v_used=+0.000
# UNI but                       v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI why                       v=+0.000 a=+0.667 d=-0.286  -> v_used=+0.000
# UNI did                       v=+0.000 a=+0.667 d=+0.000  -> v_used=+0.000
# MWE tell me                   v=+0.130 a=-0.174 d=-0.068  -> v_used=-0.130 [NEG]
# UNI before                    v=-0.038 a=-0.258 d=-0.240  -> v_used=+0.038 [NEG]
# UNI if                        v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI known                     v=+0.194 a=-0.222 d=+0.064  -> v_used=+0.194
# MWE as much                   v=+0.000 a=-0.232 d=+0.000  -> v_used=+0.000
# UNI this                      v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI morning                   v=+0.376 a=-0.530 d=-0.112  -> v_used=+0.376
# UNI certainly                 v=+0.167 a=+0.000 d=+0.417  -> v_used=+0.167
# UNI would                     v=-0.014 a=-0.176 d=-0.146  -> v_used=-0.014
# UNI have                      v=+0.514 a=-0.222 d=+0.186  -> v_used=-0.514 [NEG]
# UNI on                        v=+0.000 a=+0.000 d=+0.056  -> v_used=-0.000 [NEG]
# UNI him                       v=+0.000 a=+0.000 d=+0.037  -> v_used=+0.000
# UNI it                        v=+0.000 a=-0.282 d=+0.000  -> v_used=+0.000
# UNI is                        v=+0.000 a=+0.000 d=+0.048  -> v_used=+0.000
# UNI very                      v=+0.143 a=+0.000 d=+0.037  -> v_used=+0.143
# UNI unlucky                   v=-0.854 a=-0.210 d=-0.604  -> v_used=-0.854
# UNI but                       v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI as                        v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI have                      v=+0.514 a=-0.222 d=+0.186  -> v_used=+0.514
# UNI actually                  v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI paid                      v=+0.400 a=-0.112 d=-0.066  -> v_used=+0.400
# UNI visit                     v=+0.542 a=-0.114 d=-0.110  -> v_used=+0.542
# UNI we                        v=+0.267 a=+0.417 d=+0.417  -> v_used=+0.267
# UNI escape                    v=-0.266 a=+0.530 d=-0.104  -> v_used=+0.266 [NEG]
# UNI acquaintance              v=+0.312 a=-0.420 d=+0.340  -> v_used=-0.312 [NEG]
# UNI now                       v=+0.226 a=-0.164 d=+0.032  -> v_used=+0.226
# UNI astonishment              v=+0.360 a=+0.436 d=+0.038  -> v_used=+0.360
# UNI of                        v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI ladies                    v=+0.667 a=+0.000 d=-0.333  -> v_used=+0.667
# UNI was                       v=+0.000 a=-0.083 d=+0.000  -> v_used=+0.000
# UNI just                      v=+0.630 a=+0.000 d=+0.524  -> v_used=+0.630
# UNI what                      v=+0.000 a=+0.046 d=+0.000  -> v_used=+0.000
# UNI he                        v=+0.611 a=+0.000 d=+0.556  -> v_used=+0.611
# UNI that                      v=+0.000 a=+0.077 d=+0.000  -> v_used=+0.000
# UNI of                        v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI perhaps                   v=+0.000 a=-0.333 d=-0.333  -> v_used=+0.000
# UNI surpassing                v=+0.438 a=+0.320 d=+0.440  -> v_used=+0.438
# UNI rest                      v=+0.814 a=-0.666 d=-0.400  -> v_used=+0.814
# UNI though                    v=-0.048 a=+0.000 d=+0.000  -> v_used=-0.048
# UNI when                      v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI first                     v=+0.250 a=+0.000 d=+0.576  -> v_used=+0.250
# UNI tumult                    v=-0.458 a=+0.280 d=+0.272  -> v_used=-0.458
# UNI of                        v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI joy                       v=+0.960 a=+0.648 d=+0.588  -> v_used=+0.960
# UNI was                       v=+0.000 a=-0.083 d=+0.000  -> v_used=+0.000
# UNI over                      v=+0.000 a=+0.037 d=+0.667  -> v_used=+0.000
# UNI began                     v=-0.072 a=-0.018 d=+0.034  -> v_used=-0.072
# UNI to                        v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI declare                   v=+0.354 a=+0.246 d=+0.336  -> v_used=+0.354
# UNI that                      v=+0.000 a=+0.077 d=+0.000  -> v_used=+0.000
# UNI it                        v=+0.000 a=-0.282 d=+0.000  -> v_used=+0.000
# UNI was                       v=+0.000 a=-0.083 d=+0.000  -> v_used=+0.000
# UNI what                      v=+0.000 a=+0.046 d=+0.000  -> v_used=+0.000
# UNI expected                  v=+0.458 a=-0.176 d=+0.090  -> v_used=+0.458
# UNI all                       v=+0.000 a=+0.000 d=+0.407  -> v_used=+0.000
# UNI while                     v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI how                       v=+0.000 a=+0.000 d=+0.296  -> v_used=+0.000
# UNI good                      v=+0.876 a=-0.264 d=+0.068  -> v_used=+0.876
# UNI it                        v=+0.000 a=-0.282 d=+0.000  -> v_used=+0.000
# UNI was                       v=+0.000 a=-0.083 d=+0.000  -> v_used=+0.000
# UNI dear                      v=+0.760 a=-0.132 d=+0.258  -> v_used=+0.760
# UNI but                       v=+0.000 a=+0.000 d=+0.000  -> v_used=+0.000
# UNI knew                      v=+0.072 a=-0.066 d=-0.206  -> v_used=+0.072
# UNI should                    v=+0.083 a=-0.037 d=+0.500  -> v_used=+0.083
# UNI persuade                  v=+0.240 a=+0.236 d=+0.418  -> v_used=+0.240
# MWE at last                   v=-0.034 a=-0.276 d=-0.378  -> v_used=-0.034
#
# Aggregate: v=+0.103 a=-0.019 d=+0.041 | hits=78 / tokens=116 coverage=0.672 | MWE%=5%
#
# -- per sentence --
# [s01] v=None a=None d=None (cov=0.00) :: Mr.
# [s02] v=-0.328 a=-0.07 d=-0.155 (cov=0.40) :: Bingley." "I am sick of Mr.
# [s03] v=0.053 a=0.242 d=-0.163 (cov=0.50) :: Bingley," cried his wife.
# [s04] v=0.024 a=0.056 d=-0.128 (cov=0.71) :: "I am sorry to hear _that_; but why did you not tell me so before?
# [s05] v=0.021 a=-0.138 d=0.05 (cov=0.67) :: If I had known as much this morning, I certainly would not have called on him.
# [s06] v=0.15 a=-0.004 d=0.042 (cov=0.74) :: It is very unlucky; but as I have actually paid the visit, we cannot escape the ...
# [s07] v=0.128 a=0.001 d=0.127 (cov=0.75) :: Bennet perhaps surpassing the rest; though when the first tumult of joy was over...
# [s08] v=0.327 a=-0.152 d=0.124 (cov=0.56) :: "How good it was in you, my dear Mr.
# [s09] v=None a=None d=None (cov=0.00) :: Bennet!
# [s10] v=0.072 a=-0.029 d=0.067 (cov=0.62) :: But I knew I should persuade you at last.
